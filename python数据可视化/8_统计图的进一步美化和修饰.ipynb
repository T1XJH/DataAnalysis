# %%
# 加载matplotlib。pyplot库
import matplotlib.pyplot as plt
#让图形在notebook中自动显示
% matplotlib inline

# 加载pandas库（用于数据管理）
import pandas as pd
import numpy as np
# 加载seaborn库
import seaborn as sns
# 华文细黑是相对而言显示效果极好的中文字体
plt.rcParams["font.family"] = "STXIHEI"
sns.set(font='STXIHEI')

from matplotlib.font_manager import FontProperties
from matplotlib.font_manager import fontManager

#准备CCSS数据集
ccss = pd.read_excel("ccss_sample.xlsx")
ccss.head()
# Out:
#      time  id  s0 s2  s3     s4             s5  s7          s9 c0_1  \
# 0  200704   1  北京  男  20     本科     公司普通职员（白领）  未婚  2000-2999元    0
# 1  200704   2  北京  男  24  高中/中专     公司普通职员（白领）  未婚  6000-7999元    0
# 2  200704   3  上海  男  20  高中/中专  无业/待业/失业/家庭主妇  未婚  1000-1499元    0
# 3  200704   4  北京  女  65     大专       企/事业管理人员  已婚  1000-1499元    0
# 4  200704   5  上海  女  40  高中/中专     公司普通职员（白领）  已婚      99拒绝回答    0
#
#       ...         Qs9  Qa3  Qa4  Qa8  Qa9 Qa10  Qa16      index1     index1a  \
# 0     ...      2500.0  100  200  200  200  100   100  109.349371   88.035919
# 1     ...      7000.0  100  100  100  150  200   100   93.728032   88.035919
# 2     ...      1250.0  100  150  150  100  100   100   93.728032   88.035919
# 3     ...      1250.0  150  150  100  100  100   200  109.349371  154.062858
# 4     ...         NaN  100  100  100  100  150   100   85.917363   88.035919
#
#       index1b
# 0  121.071238
# 1   96.856991
# 2   96.856991
# 3   84.749867
# 4   84.749867
#
# [5 rows x 32 columns]

# %%
plt.plot([1,2,2,1])

# %%
# 更改图形模板
sns.set_style("white")
plt.plot([1,2,2,1])

# %%
# 更改图形模板
sns.set_style("whitegrid")
plt.plot([1,2,2,1])

# %%
# 查看Axes对象整体外风格的现有参数设定
sns.axes_style()
# Out:
# {'axes.axisbelow': True,
#  'axes.edgecolor': '.8',
#  'axes.facecolor': 'white',
#  'axes.grid': True,
#  'axes.labelcolor': '.15',
#  'axes.spines.bottom': True,
#  'axes.spines.left': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True,
#  'figure.facecolor': 'white',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'image.cmap': 'rocket',
#  'lines.solid_capstyle': 'round',
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'text.color': '.15',
#  'xtick.bottom': False,
#  'xtick.color': '.15',
#  'xtick.direction': 'out',
#  'xtick.top': False,
#  'ytick.color': '.15',
#  'ytick.direction': 'out',
#  'ytick.left': False,
#  'ytick.right': False}

# %%
# 直接修改个别参数
sns.set_style({'ytick.left':True, 'xtick.top':True})
plt.plot([1,2])

# %%
# 在默认主题的基础上进行修改
sns.set_style("dark", {"axes.facecolor":"c"})
plt.plot([1,2,2,1])

# %%
# 查看绘图元素大小现有设定
sns.plotting_context()
# Out:
# {'axes.labelsize': 12.0,
#  'axes.linewidth': 1.25,
#  'axes.titlesize': 12.0,
#  'font.size': 12.0,
#  'grid.linewidth': 1.0,
#  'legend.fontsize': 11.0,
#  'lines.linewidth': 1.5,
#  'lines.markersize': 6.0,
#  'patch.linewidth': 1.0,
#  'xtick.labelsize': 11.0,
#  'xtick.major.size': 6.0,
#  'xtick.major.width': 1.25,
#  'xtick.minor.size': 4.0,
#  'xtick.minor.width': 1.0,
#  'ytick.labelsize': 11.0,
#  'ytick.major.size': 6.0,
#  'ytick.major.width': 1.25,
#  'ytick.minor.size': 4.0,
#  'ytick.minor.width': 1.0}

# %%
sns.set_style("ticks")
sns.set_context({'xtick.labelsize':20, 'ytick.major.size':16})
plt.plot([1,2])

# %%
sns.plotting_context('paper')
# Out:
# {'axes.labelsize': 9.600000000000001,
#  'axes.linewidth': 1.0,
#  'axes.titlesize': 9.600000000000001,
#  'font.size': 9.600000000000001,
#  'grid.linewidth': 0.8,
#  'legend.fontsize': 8.8,
#  'lines.linewidth': 1.2000000000000002,
#  'lines.markersize': 4.800000000000001,
#  'patch.linewidth': 0.8,
#  'xtick.labelsize': 8.8,
#  'xtick.major.size': 4.800000000000001,
#  'xtick.major.width': 1.0,
#  'xtick.minor.size': 3.2,
#  'xtick.minor.width': 0.8,
#  'ytick.labelsize': 8.8,
#  'ytick.major.size': 4.800000000000001,
#  'ytick.major.width': 1.0,
#  'ytick.minor.size': 3.2,
#  'ytick.minor.width': 0.8}

# %%
sns.set_context('paper')
plt.plot([1,2])

# %%
# 重新载入默认样式定义
sns.set(font='STXIHEI')
plt.plot([1,2])

# %%
sns.color_palette()
# Out:
# [(0.29803921568627451, 0.44705882352941179, 0.69019607843137254),
#  (0.8666666666666667, 0.51764705882352946, 0.32156862745098042),
#  (0.33333333333333331, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.30588235294117649, 0.32156862745098042),
#  (0.50588235294117645, 0.44705882352941179, 0.70196078431372544),
#  (0.57647058823529407, 0.47058823529411764, 0.37647058823529411),
#  (0.85490196078431369, 0.54509803921568623, 0.76470588235294112),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.80000000000000004, 0.72549019607843135, 0.45490196078431372),
#  (0.39215686274509803, 0.70980392156862748, 0.80392156862745101)]

# %%
sns.palplot(sns.color_palette('bright'))

# %%
sns.set_palette('bright')
plt.plot([1,2])

# %%
# 改变系统设定
sns.set(context = 'talk', style = 'whitegrid', palette = 'bright')
plt.plot([1,2])

# %%
sns.set(context = 'paper', style = 'white', palette = 'dark')
plt.plot([1,2])

# %%
# 当不提供任何参数是，直接加默认设定
#sns.set()

# %%
def sinplot(flip = 1):
    x = np.linspace(0, 14, 100)
    for i in range(1,7):
        plt.plot(x, np.sin(x + i * .5)*(7-i)*flip)

with sns.axes_style("darkgrid"):
    plt.subplot(211)
    sinplot()
    
sns.set_style("whitegrid")
plt.subplot(212)
sinplot()

# %%
# 设置坐标轴
# 设置边框颜色(不用sns.set())
plt.plot([1,2,2,1])
plt.gca().spines['left'].set_color('y')
plt.gca().spines['right'].set_color('g')
plt.gca().spines['bottom'].set_color('c')
plt.gca().spines['top'].set_color('b')

# %%
# 设置边框线宽和线形(不用sns.set())
plt.plot([1,2,2,1])
ax1 = plt.gca()
ax1.spines['left'].set_lw(2.5)
ax1.spines['left'].set_ls(':')
ax1.spines['bottom'].set_lw('2.5')
ax1.spines['bottom'].set_ls('--')
ax1.spines['right'].set_color('w')
ax1.spines['top'].set_color('none')

# %%
plt.xlabel('$label$', fontdict = {'family': 'serif',
                                  'color': 'red',
                                  'weight': 'normal', 
                                  'size': 16})
# Out:
# Text(0.5,0,'$label$')

# %%
# 设置坐标轴刻度范围
xmin, xmax = plt.xlim()
print(xmin, xmax)
plt.xlim(0, 0.5)
# Out:
# 0.0 1.0
# (0, 0.5)

# %%
plt.xticks(rotation = 'vertical') # 使用了matplotlib.text类的方法
plt.yticks([-2, -1.5, -1, 1.5, 3],
           ['really bad', 'bad', 'normal', 'good', 'really good'],
           color = 'green')
# Out:
# ([<matplotlib.axis.YTick at 0x10107f70>,
#   <matplotlib.axis.YTick at 0x10107850>,
#   <matplotlib.axis.YTick at 0x100f7330>,
#   <matplotlib.axis.YTick at 0x100e3610>,
#   <matplotlib.axis.YTick at 0x100c4810>],
#  <a list of 5 Text yticklabel objects>)

# %%
# 使用转义字符串进行格式化
# 可进一步使用LeTex转义字符（注意和中文不兼容）
plt.xticks(rotation = 'vertical') # 使用了matplotlib。text类的方法
plt.yticks([-2, -1.5, -1, 1.5, 3],
           ['$really\ bad$', '$bad$', r'$normal\ \alpha\ level$',
            '$good$', '$really\ good$'],
           color = 'green')
# Out:
# ([<matplotlib.axis.YTick at 0x10121170>,
#   <matplotlib.axis.YTick at 0x101a7fb0>,
#   <matplotlib.axis.YTick at 0x101c3a30>,
#   <matplotlib.axis.YTick at 0x10977390>,
#   <matplotlib.axis.YTick at 0x10982370>],
#  <a list of 5 Text yticklabel objects>)

# %%
ax = plt.gca()
# ACCEPTS:{'top' \ 'bottom' \ 'both' \ 'default' \ 'none'}
ax.xaxis.set_ticks_position('top') # 选择下方的边界用于显示刻度
ax.yaxis.set_ticks_position('right') # 选择右侧的边界用于显示刻度

# %%
# 移动坐标轴位置
ax = plt.gca()

# the lst is in 'outward' \ 'axes' \ 'data'
ax.spines['bottom'].set_position(('data', 0.5)) # 下方边界交叉于0.5位置
ax.spines['left'].set_position(('data', 0.5)) # 左侧边界交叉于0。5位置

# %%
# 来点复杂的图形
t = np.linspace(-3, 3, 100)

x = 16*(np.sin(t))**3
y = 13*np.cos(t)-5*np.cos(2*t)-2*np.cos(3*t)-np.cos(4*t)

a = plt.figure(figsize = (5,5))
plt.plot(x, y)

ax = plt.gca()

ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# %%
# 移除坐标轴
sns.set_style('white')
sns.distplot(ccss.s3)

# %%
sns.distplot(ccss.s3)
sns.despine()

# %%
# 有针对性的移除某些边框
sns.distplot(ccss.s3)
sns.despine(bottom = True)

# %%
sns.violinplot(ccss.s3)
sns.despine(offset = 10)

# %%
sns.violinplot(ccss.s3)
sns.despine(offset = 10, trim = True)

# %%
# offset可以设置为负值
sns.violinplot(ccss.s3)
sns.despine(offset = -20)

# %%
sns.violinplot(ccss.s3)
sns.despine(offset = {'left': -20})

# %%
x = np.linspace(-3,3,50)
y = 2 * x + 1

plt.figure(figsize=(8,5))
plt.plot(x,y)

ax = plt.gca()
sns.despine()
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data', 0))

plt.plot([1,1], [0, 3], 'k--', linewidth = 2.5)
plt.scatter([1], [3], s = 50, color = 'b')

plt.annotate('$2x+1=3$', xy=(1,3), xycoords = 'data',xytext = (+30, -10), 
             textcoords = 'offset points', fontsize = 16)
# Out:
# Text(30,-10,'$2x+1=3$')

# %%
#与notebook有兼容问题，箭头不显示
x = np.linspace(-3,3,50)
y = 2 * x + 1

plt.figure(figsize=(8,5))
plt.plot(x,y)

ax = plt.gca()
sns.despine()
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data', 0))

plt.plot([1,1], [0, 3], 'k--', linewidth = 2.5)
plt.scatter([1], [3], s = 50, color = 'b')

plt.annotate('$2x+1=3$', xy=(1,3), xycoords = 'data',xytext = (+30, -10), 
             textcoords = 'offset points', fontsize = 16,
             arrowprops = dict(arrowstyle = '->',
                               connectionstyle = "arc3, rad = .2"))
# Out:
# Text(30,-10,'$2x+1=3$')

# %%
plt.text(0.6, 0.5, "$The\ tag\ 1$", size = 50, rotation = 30,
         ha = "center", va = "center",
         bbox = dict(boxstyle = "round",
                     ec = (1, 0.5, 0.5),
                     fc = (1, 0.8, 0.8)
                    )
        )
plt.text(0.5, 0.4, "tag2", size = 50, rotation = -30,
         ha = "right", va = "top",
         bbox = dict(boxstyle = "square",
                     ec = (0, 1, 1),
                     fc = (1, 0, 0)
                    )
        )
# Out:
# Text(0.5,0.4,'tag2')

# %%
# 获得所有可用的字体列表
from matplotlib.font_manager import fontManager

fonts = list(f.name for f in fontManager.ttflist)
fontname = list(f.fname for f in fontManager.ttflist)

print('可用字体：')
for i in range(len(fonts)):
    print(fonts[i] + " : " + fontname[i])
# Out:
# 可用字体：
# DejaVu Serif : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\DejaVuSerif-Bold.ttf
# STIXGeneral : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXGeneral.ttf
# cmex10 : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\cmex10.ttf
# STIXSizeTwoSym : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXSizTwoSymBol.ttf
# cmmi10 : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\cmmi10.ttf
# cmsy10 : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\cmsy10.ttf
# STIXSizeOneSym : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXSizOneSymBol.ttf
# STIXSizeFiveSym : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXSizFiveSymReg.ttf
# DejaVu Sans : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\DejaVuSans.ttf
# cmss10 : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\cmss10.ttf
# STIXNonUnicode : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXNonUniIta.ttf
# STIXSizeTwoSym : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXSizTwoSymReg.ttf
# DejaVu Sans Mono : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\DejaVuSansMono-BoldOblique.ttf
# STIXSizeFourSym : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXSizFourSymReg.ttf
# STIXSizeOneSym : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXSizOneSymReg.ttf
# DejaVu Sans Mono : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\DejaVuSansMono.ttf
# DejaVu Sans Mono : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\DejaVuSansMono-Bold.ttf
# DejaVu Sans : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\DejaVuSans-Oblique.ttf
# DejaVu Sans Display : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\DejaVuSansDisplay.ttf
# STIXSizeFourSym : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXSizFourSymBol.ttf
# DejaVu Sans : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\DejaVuSans-BoldOblique.ttf
# cmb10 : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\cmb10.ttf
# DejaVu Serif Display : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\DejaVuSerifDisplay.ttf
# STIXGeneral : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXGeneralItalic.ttf
# DejaVu Serif : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\DejaVuSerif.ttf
# DejaVu Sans Mono : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\DejaVuSansMono-Oblique.ttf
# STIXNonUnicode : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXNonUni.ttf
# STIXNonUnicode : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXNonUniBolIta.ttf
# STIXGeneral : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXGeneralBolIta.ttf
# DejaVu Serif : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\DejaVuSerif-BoldItalic.ttf
# STIXSizeThreeSym : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXSizThreeSymBol.ttf
# STIXGeneral : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXGeneralBol.ttf
# DejaVu Sans : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\DejaVuSans-Bold.ttf
# cmr10 : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\cmr10.ttf
# STIXNonUnicode : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXNonUniBol.ttf
# STIXSizeThreeSym : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\STIXSizThreeSymReg.ttf
# cmtt10 : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\cmtt10.ttf
# DejaVu Serif : c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\mpl-data\fonts\ttf\DejaVuSerif-Italic.ttf
# Calibri : C:\WINDOWS\Fonts\calibril.ttf
# Segoe UI : C:\WINDOWS\Fonts\segoeuiz.ttf
# Lucida Fax : c:\windows\fonts\lfaxdi.ttf
# Palatino Linotype : C:\WINDOWS\Fonts\palai.ttf
# Verdana : C:\WINDOWS\Fonts\verdanai.ttf
# Informal Roman : C:\WINDOWS\Fonts\INFROMAN.TTF
# Elephant : c:\windows\fonts\elephnti.ttf
# STSong : C:\WINDOWS\Fonts\STSONG.TTF
# Times New Roman : C:\WINDOWS\Fonts\timesbd.ttf
# Microsoft Tai Le : C:\WINDOWS\Fonts\taileb.ttf
# Lucida Calligraphy : C:\WINDOWS\Fonts\LCALLIG.TTF
# Segoe UI : c:\windows\fonts\seguili.ttf
# Segoe UI Symbol : c:\windows\fonts\seguisym.ttf
# Gill Sans MT : C:\WINDOWS\Fonts\GIL_____.TTF
# Franklin Gothic Heavy : c:\windows\fonts\frahvit.ttf
# Tempus Sans ITC : C:\WINDOWS\Fonts\TEMPSITC.TTF
# Constantia : C:\WINDOWS\Fonts\constanz.ttf
# Monotype Corsiva : C:\WINDOWS\Fonts\MTCORSVA.TTF
# Franklin Gothic Medium : c:\windows\fonts\framd.ttf
# STKaiti : c:\windows\fonts\stkaiti.ttf
# Century Schoolbook : c:\windows\fonts\censcbk.ttf
# Wide Latin : c:\windows\fonts\latinwd.ttf
# Vladimir Script : C:\WINDOWS\Fonts\VLADIMIR.TTF
# Lucida Sans Typewriter : C:\WINDOWS\Fonts\LTYPEB.TTF
# Bookman Old Style : C:\WINDOWS\Fonts\BOOKOS.TTF
# KaiTi : C:\WINDOWS\Fonts\simkai.ttf
# Franklin Gothic Book : c:\windows\fonts\frabk.ttf
# Calibri : C:\WINDOWS\Fonts\calibriz.ttf
# Tahoma : c:\windows\fonts\tahomabd.ttf
# FZShuTi : C:\WINDOWS\Fonts\FZSTK.TTF
# Microsoft PhagsPa : c:\windows\fonts\phagspa.ttf
# STLiti : c:\windows\fonts\stliti.ttf
# Trebuchet MS : C:\WINDOWS\Fonts\trebuc.ttf
# Segoe UI : C:\WINDOWS\Fonts\seguisli.ttf
# Segoe UI : c:\windows\fonts\seguibli.ttf
# Book Antiqua : c:\windows\fonts\antquab.ttf
# Arial : c:\windows\fonts\arial.ttf
# Tw Cen MT : c:\windows\fonts\tcb_____.ttf
# Rockwell Condensed : C:\WINDOWS\Fonts\ROCCB___.TTF
# Segoe UI : c:\windows\fonts\segoeuii.ttf
# Palatino Linotype : C:\WINDOWS\Fonts\palab.ttf
# Rockwell : C:\WINDOWS\Fonts\ROCKBI.TTF
# Bodoni MT : c:\windows\fonts\bod_cr.ttf
# Symbol : c:\windows\fonts\symbol.ttf
# Wingdings 3 : C:\WINDOWS\Fonts\WINGDNG3.TTF
# Lucida Sans : c:\windows\fonts\lsansdi.ttf
# Tw Cen MT Condensed Extra Bold : C:\WINDOWS\Fonts\TCCEB.TTF
# Consolas : c:\windows\fonts\consolaz.ttf
# Comic Sans MS : C:\WINDOWS\Fonts\comic.ttf
# Bodoni MT : C:\WINDOWS\Fonts\BOD_I.TTF
# Candara : c:\windows\fonts\candara.ttf
# Eras Light ITC : c:\windows\fonts\eraslght.ttf
# Century Schoolbook : c:\windows\fonts\schlbkb.ttf
# Palatino Linotype : c:\windows\fonts\palabi.ttf
# Agency FB : c:\windows\fonts\agencyb.ttf
# MT Extra : C:\WINDOWS\Fonts\mtextra.ttf
# Gill Sans MT : c:\windows\fonts\gilb____.ttf
# Candara : C:\WINDOWS\Fonts\Candarab.ttf
# Segoe Script : C:\WINDOWS\Fonts\segoescb.ttf
# Arial : C:\WINDOWS\Fonts\ariblk.ttf
# Segoe UI Emoji : c:\windows\fonts\seguiemj.ttf
# Old English Text MT : c:\windows\fonts\oldengl.ttf
# Imprint MT Shadow : c:\windows\fonts\imprisha.ttf
# Gadugi : C:\WINDOWS\Fonts\gadugib.ttf
# Arial Unicode MS : C:\WINDOWS\Fonts\ARIALUNI.TTF
# Georgia : C:\WINDOWS\Fonts\georgiab.ttf
# Bodoni MT : C:\WINDOWS\Fonts\BOD_B.TTF
# Eras Light ITC : C:\WINDOWS\Fonts\ERASLGHT.TTF
# Juice ITC : C:\WINDOWS\Fonts\JUICE___.TTF
# Lucida Sans Typewriter : c:\windows\fonts\ltypebo.ttf
# Wingdings : C:\WINDOWS\Fonts\wingding.ttf
# Bodoni MT : c:\windows\fonts\bod_r.ttf
# Franklin Gothic Book : C:\WINDOWS\Fonts\FRABKIT.TTF
# Parchment : C:\WINDOWS\Fonts\PARCHM.TTF
# Freestyle Script : c:\windows\fonts\freescpt.ttf
# FZYaoTi : C:\WINDOWS\Fonts\FZYTK.TTF
# Bauhaus 93 : C:\WINDOWS\Fonts\BAUHS93.TTF
# Gabriola : C:\WINDOWS\Fonts\Gabriola.ttf
# STHupo : c:\windows\fonts\sthupo.ttf
# Mongolian Baiti : C:\WINDOWS\Fonts\monbaiti.ttf
# Lucida Sans Unicode : C:\WINDOWS\Fonts\l_10646.ttf
# MS Outlook : c:\windows\fonts\outlook.ttf
# Trebuchet MS : C:\WINDOWS\Fonts\trebucbd.ttf
# Californian FB : c:\windows\fonts\califi.ttf
# Segoe Print : c:\windows\fonts\segoepr.ttf
# Times New Roman : c:\windows\fonts\timesi.ttf
# Tempus Sans ITC : c:\windows\fonts\tempsitc.ttf
# Tw Cen MT : c:\windows\fonts\tcm_____.ttf
# OCR A Extended : c:\windows\fonts\ocraext.ttf
# Perpetua : c:\windows\fonts\peri____.ttf
# Calibri : C:\WINDOWS\Fonts\calibrili.ttf
# French Script MT : C:\WINDOWS\Fonts\FRSCRIPT.TTF
# Palatino Linotype : C:\WINDOWS\Fonts\pala.ttf
# Ebrima : c:\windows\fonts\ebrimabd.ttf
# Consolas : C:\WINDOWS\Fonts\consola.ttf
# Pristina : c:\windows\fonts\pristina.ttf
# Rockwell : c:\windows\fonts\rockbi.ttf
# Edwardian Script ITC : C:\WINDOWS\Fonts\ITCEDSCR.TTF
# Berlin Sans FB : C:\WINDOWS\Fonts\BRLNSB.TTF
# Myanmar Text : C:\WINDOWS\Fonts\mmrtext.ttf
# STKaiti : C:\WINDOWS\Fonts\STKAITI.TTF
# Segoe UI : c:\windows\fonts\seguisbi.ttf
# Lucida Sans Typewriter : C:\WINDOWS\Fonts\LTYPEO.TTF
# Ink Free : c:\windows\fonts\inkfree.ttf
# Arial : C:\WINDOWS\Fonts\ARIALNB.TTF
# Blackadder ITC : c:\windows\fonts\itcblkad.ttf
# Ebrima : C:\WINDOWS\Fonts\ebrima.ttf
# Wingdings 2 : C:\WINDOWS\Fonts\WINGDNG2.TTF
# Perpetua Titling MT : c:\windows\fonts\pertibd.ttf
# Lucida Console : C:\WINDOWS\Fonts\lucon.ttf
# Franklin Gothic Heavy : c:\windows\fonts\frahv.ttf
# Century Gothic : C:\WINDOWS\Fonts\GOTHICBI.TTF
# Tw Cen MT : C:\WINDOWS\Fonts\TCB_____.TTF
# STHupo : C:\WINDOWS\Fonts\STHUPO.TTF
# Jokerman : c:\windows\fonts\jokerman.ttf
# YouYuan : C:\WINDOWS\Fonts\SIMYOU.TTF
# Comic Sans MS : c:\windows\fonts\comicz.ttf
# Maiandra GD : c:\windows\fonts\maian.ttf
# Malgun Gothic : c:\windows\fonts\malgunsl.ttf
# Segoe Script : C:\WINDOWS\Fonts\segoesc.ttf
# Candara : C:\WINDOWS\Fonts\Candara.ttf
# Nirmala UI : c:\windows\fonts\nirmalab.ttf
# Agency FB : C:\WINDOWS\Fonts\AGENCYR.TTF
# Constantia : C:\WINDOWS\Fonts\constani.ttf
# Bodoni MT : C:\WINDOWS\Fonts\BOD_CR.TTF
# Rockwell Condensed : c:\windows\fonts\roccb___.ttf
# Vladimir Script : c:\windows\fonts\vladimir.ttf
# Courier New : c:\windows\fonts\courbi.ttf
# Garamond : C:\WINDOWS\Fonts\GARABD.TTF
# Gill Sans Ultra Bold Condensed : c:\windows\fonts\gillubcd.ttf
# Segoe Print : c:\windows\fonts\segoeprb.ttf
# Calisto MT : C:\WINDOWS\Fonts\CALISTI.TTF
# Verdana : C:\WINDOWS\Fonts\verdanaz.ttf
# Californian FB : C:\WINDOWS\Fonts\CALIFB.TTF
# Microsoft New Tai Lue : c:\windows\fonts\ntailub.ttf
# Georgia : C:\WINDOWS\Fonts\georgia.ttf
# Script MT Bold : C:\WINDOWS\Fonts\SCRIPTBL.TTF
# Georgia : C:\WINDOWS\Fonts\georgiaz.ttf
# Arial : C:\WINDOWS\Fonts\ariali.ttf
# Corbel : c:\windows\fonts\corbelb.ttf
# Gadugi : C:\WINDOWS\Fonts\gadugi.ttf
# Cooper Black : c:\windows\fonts\coopbl.ttf
# Microsoft Tai Le : c:\windows\fonts\taile.ttf
# STFangsong : c:\windows\fonts\stfangso.ttf
# Book Antiqua : C:\WINDOWS\Fonts\ANTQUAI.TTF
# SimSun-ExtB : C:\WINDOWS\Fonts\simsunb.ttf
# Ravie : c:\windows\fonts\ravie.ttf
# Arial : c:\windows\fonts\arialnbi.ttf
# Leelawadee UI : C:\WINDOWS\Fonts\LeelUIsl.ttf
# Bodoni MT : C:\WINDOWS\Fonts\BOD_BI.TTF
# Malgun Gothic : C:\WINDOWS\Fonts\malgunbd.ttf
# DengXian : c:\windows\fonts\deng.ttf
# Tw Cen MT : c:\windows\fonts\tcbi____.ttf
# Lucida Fax : C:\WINDOWS\Fonts\LFAXD.TTF
# YouYuan : c:\windows\fonts\simyou.ttf
# Book Antiqua : c:\windows\fonts\antquai.ttf
# Playbill : C:\WINDOWS\Fonts\PLAYBILL.TTF
# Stencil : C:\WINDOWS\Fonts\STENCIL.TTF
# Informal Roman : c:\windows\fonts\infroman.ttf
# Book Antiqua : c:\windows\fonts\bkant.ttf
# Haettenschweiler : C:\WINDOWS\Fonts\HATTEN.TTF
# High Tower Text : C:\WINDOWS\Fonts\HTOWERTI.TTF
# Perpetua : C:\WINDOWS\Fonts\PERI____.TTF
# Copperplate Gothic Bold : c:\windows\fonts\coprgtb.ttf
# Consolas : c:\windows\fonts\consolai.ttf
# Bahnschrift : c:\windows\fonts\bahnschrift.ttf
# Georgia : c:\windows\fonts\georgiai.ttf
# Californian FB : c:\windows\fonts\califr.ttf
# Corbel : C:\WINDOWS\Fonts\corbeli.ttf
# Segoe UI Historic : c:\windows\fonts\seguihis.ttf
# Baskerville Old Face : c:\windows\fonts\baskvill.ttf
# Courier New : C:\WINDOWS\Fonts\courbd.ttf
# Californian FB : C:\WINDOWS\Fonts\CALIFR.TTF
# Curlz MT : C:\WINDOWS\Fonts\CURLZ___.TTF
# Lucida Sans : C:\WINDOWS\Fonts\LSANSDI.TTF
# Leelawadee UI : c:\windows\fonts\leelawui.ttf
# Bodoni MT : c:\windows\fonts\bod_pstc.ttf
# STSong : c:\windows\fonts\stsong.ttf
# Gill Sans MT Ext Condensed Bold : c:\windows\fonts\glsnecb.ttf
# STZhongsong : c:\windows\fonts\stzhongs.ttf
# Lucida Handwriting : c:\windows\fonts\lhandw.ttf
# Gill Sans MT : c:\windows\fonts\gili____.ttf
# Segoe UI : c:\windows\fonts\seguisb.ttf
# Segoe UI : c:\windows\fonts\seguibl.ttf
# Microsoft New Tai Lue : C:\WINDOWS\Fonts\ntailu.ttf
# Segoe UI : C:\WINDOWS\Fonts\segoeui.ttf
# Courier New : c:\windows\fonts\couri.ttf
# Tw Cen MT Condensed : c:\windows\fonts\tccb____.ttf
# Bookman Old Style : c:\windows\fonts\bookosb.ttf
# Bauhaus 93 : c:\windows\fonts\bauhs93.ttf
# Candara : c:\windows\fonts\candaraz.ttf
# Century Gothic : C:\WINDOWS\Fonts\GOTHICI.TTF
# Tw Cen MT : C:\WINDOWS\Fonts\TCM_____.TTF
# Calibri : c:\windows\fonts\calibrii.ttf
# Franklin Gothic Demi Cond : c:\windows\fonts\fradmcn.ttf
# Arial : c:\windows\fonts\arialbd.ttf
# Goudy Old Style : C:\WINDOWS\Fonts\GOUDOSB.TTF
# Vivaldi : C:\WINDOWS\Fonts\VIVALDII.TTF
# Lucida Bright : C:\WINDOWS\Fonts\LBRITEI.TTF
# Showcard Gothic : c:\windows\fonts\showg.ttf
# Copperplate Gothic Light : C:\WINDOWS\Fonts\COPRGTL.TTF
# Goudy Old Style : c:\windows\fonts\goudosi.ttf
# Courier New : c:\windows\fonts\cour.ttf
# Bookman Old Style : C:\WINDOWS\Fonts\BOOKOSI.TTF
# Footlight MT Light : C:\WINDOWS\Fonts\FTLTLT.TTF
# Ink Free : C:\WINDOWS\Fonts\Inkfree.ttf
# Berlin Sans FB : C:\WINDOWS\Fonts\BRLNSR.TTF
# Juice ITC : c:\windows\fonts\juice___.ttf
# Eras Demi ITC : c:\windows\fonts\erasdemi.ttf
# Matura MT Script Capitals : c:\windows\fonts\maturasc.ttf
# Goudy Old Style : C:\WINDOWS\Fonts\GOUDOS.TTF
# Goudy Stout : C:\WINDOWS\Fonts\GOUDYSTO.TTF
# Arial : c:\windows\fonts\arialni.ttf
# Candara : c:\windows\fonts\candarai.ttf
# Bodoni MT : c:\windows\fonts\bod_cb.ttf
# Microsoft Sans Serif : C:\WINDOWS\Fonts\micross.ttf
# FangSong : c:\windows\fonts\simfang.ttf
# Gill Sans MT Condensed : c:\windows\fonts\gilc____.ttf
# Script MT Bold : c:\windows\fonts\scriptbl.ttf
# Segoe UI : c:\windows\fonts\segoeuisl.ttf
# Sylfaen : c:\windows\fonts\sylfaen.ttf
# Forte : c:\windows\fonts\forte.ttf
# Californian FB : C:\WINDOWS\Fonts\CALIFI.TTF
# Calibri : C:\WINDOWS\Fonts\calibrib.ttf
# Wingdings 3 : c:\windows\fonts\wingdng3.ttf
# LiSu : c:\windows\fonts\simli.ttf
# Segoe MDL2 Assets : c:\windows\fonts\segmdl2.ttf
# Lucida Sans : c:\windows\fonts\lsansd.ttf
# Segoe UI : c:\windows\fonts\segoeuib.ttf
# Playbill : c:\windows\fonts\playbill.ttf
# Copperplate Gothic Light : c:\windows\fonts\coprgtl.ttf
# Centaur : C:\WINDOWS\Fonts\CENTAUR.TTF
# Eras Medium ITC : C:\WINDOWS\Fonts\ERASMD.TTF
# Franklin Gothic Medium : C:\WINDOWS\Fonts\framdit.ttf
# Engravers MT : c:\windows\fonts\engr.ttf
# Lucida Sans Typewriter : c:\windows\fonts\ltype.ttf
# Freestyle Script : C:\WINDOWS\Fonts\FREESCPT.TTF
# Century Gothic : C:\WINDOWS\Fonts\GOTHIC.TTF
# icomoon : c:\windows\fonts\iqiyi_logov6.ttf
# Bell MT : c:\windows\fonts\bellb.ttf
# Tahoma : C:\WINDOWS\Fonts\tahoma.ttf
# Bell MT : C:\WINDOWS\Fonts\BELLB.TTF
# Microsoft Himalaya : C:\WINDOWS\Fonts\himalaya.ttf
# SimHei : c:\windows\fonts\simhei.ttf
# Showcard Gothic : C:\WINDOWS\Fonts\SHOWG.TTF
# Bookshelf Symbol 7 : c:\windows\fonts\bssym7.ttf
# Microsoft PhagsPa : C:\WINDOWS\Fonts\phagspab.ttf
# Papyrus : C:\WINDOWS\Fonts\PAPYRUS.TTF
# Bell MT : C:\WINDOWS\Fonts\BELL.TTF
# Curlz MT : c:\windows\fonts\curlz___.ttf
# Century Schoolbook : C:\WINDOWS\Fonts\SCHLBKBI.TTF
# Franklin Gothic Demi Cond : C:\WINDOWS\Fonts\FRADMCN.TTF
# Rockwell Condensed : C:\WINDOWS\Fonts\ROCC____.TTF
# Elephant : C:\WINDOWS\Fonts\ELEPHNTI.TTF
# Corbel : c:\windows\fonts\corbelz.ttf
# Gabriola : c:\windows\fonts\gabriola.ttf
# Arial Rounded MT Bold : C:\WINDOWS\Fonts\ARLRDBD.TTF
# Lucida Sans Typewriter : C:\WINDOWS\Fonts\LTYPE.TTF
# Niagara Solid : C:\WINDOWS\Fonts\NIAGSOL.TTF
# Garamond : c:\windows\fonts\garait.ttf
# FZShuTi : c:\windows\fonts\fzstk.ttf
# Felix Titling : c:\windows\fonts\felixti.ttf
# Rockwell Condensed : c:\windows\fonts\rocc____.ttf
# Garamond : c:\windows\fonts\garabd.ttf
# Harlow Solid Italic : C:\WINDOWS\Fonts\HARLOWSI.TTF
# Tw Cen MT Condensed : C:\WINDOWS\Fonts\TCCB____.TTF
# OCR A Extended : C:\WINDOWS\Fonts\OCRAEXT.TTF
# Leelawadee UI : c:\windows\fonts\leeluisl.ttf
# Myanmar Text : C:\WINDOWS\Fonts\mmrtextb.ttf
# Cambria : C:\WINDOWS\Fonts\cambriai.ttf
# Forte : C:\WINDOWS\Fonts\FORTE.TTF
# MS Reference Sans Serif : c:\windows\fonts\refsan.ttf
# Bodoni MT : c:\windows\fonts\bod_cbi.ttf
# Onyx : c:\windows\fonts\onyx.ttf
# Ravie : C:\WINDOWS\Fonts\RAVIE.TTF
# Webdings : C:\WINDOWS\Fonts\webdings.ttf
# Calisto MT : c:\windows\fonts\calist.ttf
# Gloucester MT Extra Condensed : C:\WINDOWS\Fonts\GLECB.TTF
# Bookshelf Symbol 7 : C:\WINDOWS\Fonts\BSSYM7.TTF
# Lucida Calligraphy : c:\windows\fonts\lcallig.ttf
# Goudy Old Style : C:\WINDOWS\Fonts\GOUDOSI.TTF
# Franklin Gothic Demi : C:\WINDOWS\Fonts\FRADM.TTF
# Javanese Text : C:\WINDOWS\Fonts\javatext.ttf
# LiSu : C:\WINDOWS\Fonts\SIMLI.TTF
# Gill Sans MT : C:\WINDOWS\Fonts\GILB____.TTF
# Perpetua : C:\WINDOWS\Fonts\PERBI___.TTF
# Chiller : c:\windows\fonts\chiller.ttf
# Haettenschweiler : c:\windows\fonts\hatten.ttf
# Tw Cen MT : C:\WINDOWS\Fonts\TCBI____.TTF
# Cambria : c:\windows\fonts\cambriab.ttf
# Algerian : c:\windows\fonts\alger.ttf
# Century Schoolbook : C:\WINDOWS\Fonts\SCHLBKB.TTF
# Eras Bold ITC : c:\windows\fonts\erasbd.ttf
# Trebuchet MS : c:\windows\fonts\trebucit.ttf
# Lucida Sans Typewriter : c:\windows\fonts\ltypeb.ttf
# Impact : c:\windows\fonts\impact.ttf
# Gloucester MT Extra Condensed : c:\windows\fonts\glecb.ttf
# Gill Sans MT Ext Condensed Bold : C:\WINDOWS\Fonts\GLSNECB.TTF
# Bodoni MT : c:\windows\fonts\bod_blai.ttf
# Lucida Handwriting : C:\WINDOWS\Fonts\LHANDW.TTF
# Gill Sans Ultra Bold : c:\windows\fonts\gilsanub.ttf
# Berlin Sans FB : c:\windows\fonts\brlnsb.ttf
# Harrington : C:\WINDOWS\Fonts\HARNGTON.TTF
# Bodoni MT : C:\WINDOWS\Fonts\BOD_R.TTF
# Arial : c:\windows\fonts\arialn.ttf
# Elephant : C:\WINDOWS\Fonts\ELEPHNT.TTF
# Tw Cen MT : c:\windows\fonts\tcmi____.ttf
# Goudy Old Style : c:\windows\fonts\goudos.ttf
# Century Gothic : c:\windows\fonts\gothici.ttf
# Marlett : C:\WINDOWS\Fonts\marlett.ttf
# Leelawadee UI : C:\WINDOWS\Fonts\LeelaUIb.ttf
# Kunstler Script : c:\windows\fonts\kunstler.ttf
# Tw Cen MT : C:\WINDOWS\Fonts\TCMI____.TTF
# Gill Sans MT : C:\WINDOWS\Fonts\GILBI___.TTF
# Bodoni MT : c:\windows\fonts\bod_i.ttf
# Harrington : c:\windows\fonts\harngton.ttf
# Book Antiqua : C:\WINDOWS\Fonts\BKANT.TTF
# Viner Hand ITC : c:\windows\fonts\vineritc.ttf
# Verdana : C:\WINDOWS\Fonts\verdanab.ttf
# Franklin Gothic Demi : c:\windows\fonts\fradm.ttf
# Cooper Black : C:\WINDOWS\Fonts\COOPBL.TTF
# Century : c:\windows\fonts\century.ttf
# Perpetua Titling MT : C:\WINDOWS\Fonts\PERTILI.TTF
# Bodoni MT : C:\WINDOWS\Fonts\BOD_CI.TTF
# Bodoni MT : c:\windows\fonts\bod_ci.ttf
# STXinwei : c:\windows\fonts\stxinwei.ttf
# Lucida Fax : C:\WINDOWS\Fonts\LFAXI.TTF
# Nirmala UI : C:\WINDOWS\Fonts\Nirmala.ttf
# Perpetua : C:\WINDOWS\Fonts\PERB____.TTF
# Palace Script MT : C:\WINDOWS\Fonts\PALSCRI.TTF
# Arial : c:\windows\fonts\arialbi.ttf
# Castellar : C:\WINDOWS\Fonts\CASTELAR.TTF
# Malgun Gothic : C:\WINDOWS\Fonts\malgun.ttf
# Constantia : c:\windows\fonts\constan.ttf
# Centaur : c:\windows\fonts\centaur.ttf
# Brush Script MT : c:\windows\fonts\brushsci.ttf
# DengXian : C:\WINDOWS\Fonts\Dengb.ttf
# Lucida Bright : c:\windows\fonts\lbrite.ttf
# Eras Demi ITC : C:\WINDOWS\Fonts\ERASDEMI.TTF
# Gill Sans Ultra Bold : C:\WINDOWS\Fonts\GILSANUB.TTF
# Lucida Bright : C:\WINDOWS\Fonts\LBRITEDI.TTF
# Microsoft Yi Baiti : c:\windows\fonts\msyi.ttf
# Gigi : C:\WINDOWS\Fonts\GIGI.TTF
# Calisto MT : c:\windows\fonts\calisti.ttf
# Bookman Old Style : C:\WINDOWS\Fonts\BOOKOSB.TTF
# Castellar : c:\windows\fonts\castelar.ttf
# Perpetua : c:\windows\fonts\perb____.ttf
# STXingkai : C:\WINDOWS\Fonts\STXINGKA.TTF
# Harlow Solid Italic : c:\windows\fonts\harlowsi.ttf
# Constantia : C:\WINDOWS\Fonts\constanb.ttf
# Garamond : C:\WINDOWS\Fonts\GARAIT.TTF
# STXihei : c:\windows\fonts\stxihei.ttf
# Lucida Bright : C:\WINDOWS\Fonts\LBRITED.TTF
# Mistral : c:\windows\fonts\mistral.ttf
# Rockwell : c:\windows\fonts\rockb.ttf
# Matura MT Script Capitals : C:\WINDOWS\Fonts\MATURASC.TTF
# DengXian : c:\windows\fonts\dengl.ttf
# Agency FB : c:\windows\fonts\agencyr.ttf
# Goudy Old Style : c:\windows\fonts\goudosb.ttf
# Chiller : C:\WINDOWS\Fonts\CHILLER.TTF
# Segoe UI : c:\windows\fonts\segoeuil.ttf
# Lucida Bright : C:\WINDOWS\Fonts\LBRITE.TTF
# Algerian : C:\WINDOWS\Fonts\ALGER.TTF
# Verdana : c:\windows\fonts\verdana.ttf
# Trebuchet MS : C:\WINDOWS\Fonts\trebucbi.ttf
# High Tower Text : c:\windows\fonts\htowerti.ttf
# MV Boli : c:\windows\fonts\mvboli.ttf
# Arial Unicode MS : c:\windows\fonts\arialuni.ttf
# Lucida Fax : C:\WINDOWS\Fonts\LFAX.TTF
# Gill Sans Ultra Bold Condensed : C:\WINDOWS\Fonts\GILLUBCD.TTF
# Franklin Gothic Book : c:\windows\fonts\frabkit.ttf
# Comic Sans MS : C:\WINDOWS\Fonts\comicbd.ttf
# Bodoni MT : c:\windows\fonts\bod_blar.ttf
# Calisto MT : C:\WINDOWS\Fonts\CALISTB.TTF
# Candara : C:\WINDOWS\Fonts\Candarai.ttf
# FZYaoTi : c:\windows\fonts\fzytk.ttf
# Perpetua Titling MT : C:\WINDOWS\Fonts\PERTIBD.TTF
# Poor Richard : C:\WINDOWS\Fonts\POORICH.TTF
# Lucida Bright : c:\windows\fonts\lbrited.ttf
# STXihei : C:\WINDOWS\Fonts\STXIHEI.TTF
# Niagara Engraved : C:\WINDOWS\Fonts\NIAGENG.TTF
# Poor Richard : c:\windows\fonts\poorich.ttf
# Calibri : C:\WINDOWS\Fonts\calibri.ttf
# Colonna MT : C:\WINDOWS\Fonts\COLONNA.TTF
# STFangsong : C:\WINDOWS\Fonts\STFANGSO.TTF
# Franklin Gothic Medium Cond : C:\WINDOWS\Fonts\FRAMDCN.TTF
# Rage Italic : c:\windows\fonts\rage.ttf
# Nirmala UI : C:\WINDOWS\Fonts\NirmalaB.ttf
# Rockwell : C:\WINDOWS\Fonts\ROCKI.TTF
# Britannic Bold : c:\windows\fonts\britanic.ttf
# Nirmala UI : c:\windows\fonts\nirmalas.ttf
# Tw Cen MT Condensed : C:\WINDOWS\Fonts\TCCM____.TTF
# Brush Script MT : C:\WINDOWS\Fonts\BRUSHSCI.TTF
# Broadway : C:\WINDOWS\Fonts\BROADW.TTF
# Lucida Bright : c:\windows\fonts\lbritei.ttf
# Bookman Old Style : c:\windows\fonts\bookosbi.ttf
# Cambria : c:\windows\fonts\cambriaz.ttf
# Monotype Corsiva : c:\windows\fonts\mtcorsva.ttf
# Bodoni MT : C:\WINDOWS\Fonts\BOD_BLAR.TTF
# Kunstler Script : C:\WINDOWS\Fonts\KUNSTLER.TTF
# Lucida Sans Typewriter : C:\WINDOWS\Fonts\LTYPEBO.TTF
# STCaiyun : c:\windows\fonts\stcaiyun.ttf
# Rage Italic : C:\WINDOWS\Fonts\RAGE.TTF
# Niagara Solid : c:\windows\fonts\niagsol.ttf
# Franklin Gothic Heavy : C:\WINDOWS\Fonts\FRAHVIT.TTF
# Mistral : C:\WINDOWS\Fonts\MISTRAL.TTF
# Kristen ITC : C:\WINDOWS\Fonts\ITCKRIST.TTF
# Century Schoolbook : c:\windows\fonts\schlbkbi.ttf
# Maiandra GD : C:\WINDOWS\Fonts\MAIAN.TTF
# Calisto MT : C:\WINDOWS\Fonts\CALISTBI.TTF
# MS Reference Specialty : c:\windows\fonts\refspcl.ttf
# Goudy Stout : c:\windows\fonts\goudysto.ttf
# Rockwell : C:\WINDOWS\Fonts\ROCKB.TTF
# Lucida Fax : c:\windows\fonts\lfax.ttf
# DengXian : C:\WINDOWS\Fonts\Dengl.ttf
# STCaiyun : C:\WINDOWS\Fonts\STCAIYUN.TTF
# Snap ITC : c:\windows\fonts\snap____.ttf
# Modern No. 20 : c:\windows\fonts\mod20.ttf
# Rockwell : C:\WINDOWS\Fonts\ROCK.TTF
# Lucida Bright : c:\windows\fonts\lbritedi.ttf
# Century Schoolbook : C:\WINDOWS\Fonts\CENSCBK.TTF
# MS Reference Specialty : C:\WINDOWS\Fonts\REFSPCL.TTF
# Imprint MT Shadow : C:\WINDOWS\Fonts\IMPRISHA.TTF
# Elephant : c:\windows\fonts\elephnt.ttf
# Franklin Gothic Medium Cond : c:\windows\fonts\framdcn.ttf
# Garamond : c:\windows\fonts\gara.ttf
# Bell MT : C:\WINDOWS\Fonts\BELLI.TTF
# High Tower Text : C:\WINDOWS\Fonts\HTOWERT.TTF
# Bookman Old Style : C:\WINDOWS\Fonts\BOOKOSBI.TTF
# Kristen ITC : c:\windows\fonts\itckrist.ttf
# Garamond : C:\WINDOWS\Fonts\GARA.TTF
# Rockwell Extra Bold : c:\windows\fonts\rockeb.ttf
# Niagara Engraved : c:\windows\fonts\niageng.ttf
# Lucida Sans : c:\windows\fonts\lsans.ttf
# Bodoni MT : C:\WINDOWS\Fonts\BOD_CB.TTF
# DengXian : C:\WINDOWS\Fonts\Deng.ttf
# Bodoni MT : C:\WINDOWS\Fonts\BOD_BLAI.TTF
# Bernard MT Condensed : c:\windows\fonts\bernhc.ttf
# STLiti : C:\WINDOWS\Fonts\STLITI.TTF
# Times New Roman : c:\windows\fonts\times.ttf
# Century Gothic : c:\windows\fonts\gothicb.ttf
# Gill Sans MT : c:\windows\fonts\gilbi___.ttf
# Nirmala UI : C:\WINDOWS\Fonts\NirmalaS.ttf
# Lucida Sans : C:\WINDOWS\Fonts\LSANS.TTF
# Bodoni MT : c:\windows\fonts\bod_bi.ttf
# Snap ITC : C:\WINDOWS\Fonts\SNAP____.TTF
# Colonna MT : c:\windows\fonts\colonna.ttf
# Gill Sans MT : c:\windows\fonts\gil_____.ttf
# Century Gothic : c:\windows\fonts\gothicbi.ttf
# Rockwell Extra Bold : C:\WINDOWS\Fonts\ROCKEB.TTF
# Arial : C:\WINDOWS\Fonts\ARIALN.TTF
# Franklin Gothic Demi : c:\windows\fonts\fradmit.ttf
# Franklin Gothic Heavy : C:\WINDOWS\Fonts\FRAHV.TTF
# MS Outlook : C:\WINDOWS\Fonts\OUTLOOK.TTF
# HoloLens MDL2 Assets : c:\windows\fonts\holomdl2.ttf
# Perpetua Titling MT : c:\windows\fonts\pertili.ttf
# STZhongsong : C:\WINDOWS\Fonts\STZHONGS.TTF
# Eras Medium ITC : c:\windows\fonts\erasmd.ttf
# DengXian : c:\windows\fonts\dengb.ttf
# Palace Script MT : c:\windows\fonts\palscri.ttf
# Lucida Sans Typewriter : c:\windows\fonts\ltypeo.ttf
# Baskerville Old Face : C:\WINDOWS\Fonts\BASKVILL.TTF
# Lucida Sans : C:\WINDOWS\Fonts\LSANSI.TTF
# Comic Sans MS : c:\windows\fonts\comici.ttf
# Wingdings 2 : c:\windows\fonts\wingdng2.ttf
# Jokerman : C:\WINDOWS\Fonts\JOKERMAN.TTF
# Blackadder ITC : C:\WINDOWS\Fonts\ITCBLKAD.TTF
# MS Reference Sans Serif : C:\WINDOWS\Fonts\REFSAN.TTF
# Nirmala UI : c:\windows\fonts\nirmala.ttf
# Candara : c:\windows\fonts\candarab.ttf
# Corbel : c:\windows\fonts\corbel.ttf
# Pristina : C:\WINDOWS\Fonts\PRISTINA.TTF
# Consolas : C:\WINDOWS\Fonts\consolab.ttf
# Book Antiqua : C:\WINDOWS\Fonts\ANTQUAB.TTF
# Bodoni MT : C:\WINDOWS\Fonts\BOD_PSTC.TTF
# Century Schoolbook : c:\windows\fonts\schlbki.ttf
# Tw Cen MT Condensed : c:\windows\fonts\tccm____.ttf
# Times New Roman : C:\WINDOWS\Fonts\timesbi.ttf
# Wide Latin : C:\WINDOWS\Fonts\LATINWD.TTF
# Candara : C:\WINDOWS\Fonts\Candaraz.ttf
# Engravers MT : C:\WINDOWS\Fonts\ENGR.TTF
# Berlin Sans FB Demi : C:\WINDOWS\Fonts\BRLNSDB.TTF
# Old English Text MT : C:\WINDOWS\Fonts\OLDENGL.TTF
# Century Gothic : c:\windows\fonts\gothic.ttf
# Bell MT : c:\windows\fonts\bell.ttf
# Bradley Hand ITC : c:\windows\fonts\bradhitc.ttf
# Gill Sans MT : C:\WINDOWS\Fonts\GILI____.TTF
# Felix Titling : C:\WINDOWS\Fonts\FELIXTI.TTF
# Magneto : c:\windows\fonts\magnetob.ttf
# Calisto MT : c:\windows\fonts\calistbi.ttf
# Californian FB : c:\windows\fonts\califb.ttf
# Bradley Hand ITC : C:\WINDOWS\Fonts\BRADHITC.TTF
# Perpetua : C:\WINDOWS\Fonts\PER_____.TTF
# Bookman Old Style : c:\windows\fonts\bookosi.ttf
# Lucida Fax : C:\WINDOWS\Fonts\LFAXDI.TTF
# Bookman Old Style : c:\windows\fonts\bookos.ttf
# Gigi : c:\windows\fonts\gigi.ttf
# Calisto MT : C:\WINDOWS\Fonts\CALIST.TTF
# Franklin Gothic Demi : C:\WINDOWS\Fonts\FRADMIT.TTF
# Onyx : C:\WINDOWS\Fonts\ONYX.TTF
# Lucida Sans : c:\windows\fonts\lsansi.ttf
# Leelawadee UI : c:\windows\fonts\leelauib.ttf
# Rockwell : c:\windows\fonts\rock.ttf
# Berlin Sans FB : c:\windows\fonts\brlnsr.ttf
# Tw Cen MT Condensed Extra Bold : c:\windows\fonts\tcceb.ttf
# Broadway : c:\windows\fonts\broadw.ttf
# Papyrus : c:\windows\fonts\papyrus.ttf
# Viner Hand ITC : C:\WINDOWS\Fonts\VINERITC.TTF
# French Script MT : c:\windows\fonts\frscript.ttf
# Bell MT : c:\windows\fonts\belli.ttf
# Arial : C:\WINDOWS\Fonts\ARIALNBI.TTF
# Eras Bold ITC : C:\WINDOWS\Fonts\ERASBD.TTF
# Century Schoolbook : C:\WINDOWS\Fonts\SCHLBKI.TTF
# Perpetua : c:\windows\fonts\perbi___.ttf
# Arial : C:\WINDOWS\Fonts\ARIALNI.TTF
# Perpetua : c:\windows\fonts\per_____.ttf
# Franklin Gothic Book : C:\WINDOWS\Fonts\FRABK.TTF
# Leelawadee UI : C:\WINDOWS\Fonts\LeelawUI.ttf
# Copperplate Gothic Bold : C:\WINDOWS\Fonts\COPRGTB.TTF
# Footlight MT Light : c:\windows\fonts\ftltlt.ttf
# Gill Sans MT Condensed : C:\WINDOWS\Fonts\GILC____.TTF
# Century : C:\WINDOWS\Fonts\CENTURY.TTF
# Lucida Fax : c:\windows\fonts\lfaxd.ttf
# Vivaldi : c:\windows\fonts\vivaldii.ttf
# High Tower Text : c:\windows\fonts\htowert.ttf
# Stencil : c:\windows\fonts\stencil.ttf
# Rockwell : c:\windows\fonts\rocki.ttf
# Berlin Sans FB Demi : c:\windows\fonts\brlnsdb.ttf
# Bodoni MT : C:\WINDOWS\Fonts\BOD_CBI.TTF
# Arial Rounded MT Bold : c:\windows\fonts\arlrdbd.ttf
# Calisto MT : c:\windows\fonts\calistb.ttf
# Modern No. 20 : C:\WINDOWS\Fonts\MOD20.TTF
# Bodoni MT : c:\windows\fonts\bod_b.ttf
# Lucida Fax : c:\windows\fonts\lfaxi.ttf
# Book Antiqua : C:\WINDOWS\Fonts\ANTQUABI.TTF
# Agency FB : C:\WINDOWS\Fonts\AGENCYB.TTF
# STXingkai : c:\windows\fonts\stxingka.ttf
# Lucida Sans : C:\WINDOWS\Fonts\LSANSD.TTF
# Parchment : c:\windows\fonts\parchm.ttf
# Century Gothic : C:\WINDOWS\Fonts\GOTHICB.TTF
# Bernard MT Condensed : C:\WINDOWS\Fonts\BERNHC.TTF
# Magneto : C:\WINDOWS\Fonts\MAGNETOB.TTF
# Edwardian Script ITC : c:\windows\fonts\itcedscr.ttf
# Arial : c:\windows\fonts\arialnb.ttf
# STXinwei : C:\WINDOWS\Fonts\STXINWEI.TTF
# Britannic Bold : C:\WINDOWS\Fonts\BRITANIC.TTF
# Book Antiqua : c:\windows\fonts\antquabi.ttf

# %%
# 在程序中指定所使用的字体
import os
import os.path

fig = plt.figure(figsize = (12,6))
ax = fig.add_subplot(111)
plt.subplots_adjust(0,0,1,1,0,0)
plt.xticks([])
plt.yticks([])
x,y = 0.05, 0.08

fonts = [font.name for font in fontManager.ttflist if os.path.exists(font.fname) and os.stat(font.fname).st_size > 2e6]
dy = (1.0-y)/(len(fonts)/4 + (len(fonts)%4!=0))
              
for font in fonts:
    t = ax.text(x,y, u"+-中文效果",{'fontname': font, 'fontsize':18},
                transform = ax.transAxes)
    ax.text(x,y - dy/2, font, transform = ax.transAxes)
    x += 0.25
    if x >= 1.0:
        y += dy
        x = 0.05
plt.show()

# %%
font1 = FontProperties(fname = 'c:\\windows\\fonts\\simsun.ttc', size = 12)
font2 = FontProperties(fname = 'c:\\windows\\fonts\\STXIHEI.TTF', size = 14)
font3 = FontProperties(fname = 'c:\\windows\\fonts\\simkai.ttf', size = 16)

sns.pointplot(x = ccss.time, y = ccss.index1, capsize =.1)
plt.xlabel("月份", fontproperties = font1)
plt.ylabel("消费者信心指数", fontproperties = font2)
plt.title("信心指数随月份变化的情况", fontproperties = font3, color = 'b')
# Out:
# Text(0.5,1,'信心指数随月份变化的情况')
